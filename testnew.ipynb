# %%
from twop_pipeline.twop.getSuite2POutput import *
from twop_pipeline.twop.TwoPAnalyze import ge


s2p_path = '/mnt/Batista_Lab/Joslyn/Experiments/VIPxTiger/dob_8.3.25/preprocessed/Back_left/p16'
s2p_out = Suite2POutput(s2p_path)
print(s2p_out.F.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from twop_pipeline.twop.getSuite2POutput import *
# ----> 2 from twop_pipeline.twop.TwoPAnalyze import *
#       4 s2p_path = '/mnt/Batista_Lab/Joslyn/Experiments/VIPxTiger/dob_8.3.25/preprocessed/Back_left/p16'
#       5 s2p_out = Suite2POutput(s2p_path)
#
# ModuleNotFoundError: No module named 'twop_pipeline.twop.TwoPAnalyze'
